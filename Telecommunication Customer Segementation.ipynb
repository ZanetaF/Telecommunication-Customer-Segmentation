# %% [markdown]
# # Zaneta Fransiske - 2702312146
# ## Case 2B (Telecommunication Customer)

# %% [markdown]
# <span style="color: red; font-size: 19px;">A. Exploratory Data Analysis (EDA) </span>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:/COOLYEAH/UAS ML/2B.csv', delimiter =",")

df.head()
# Out:
#   Customer ID  Gender  Birth Date Married Dependents  Number of Dependents  \
# 0  8779-QRDMV    Male  1946/07/17      No         No                     0
# 1  7495-OOKFY  Female  1950/11/12     Yes        Yes                     1
# 2  1658-BYGOY    Male  1953/03/21      No        Yes                     3
# 3  4598-XLKNJ  Female  1946/03/08     Yes        Yes                     1
# 4  4846-WHAFZ  Female  1944/04/02     Yes        Yes                     1
#
#          Country         City  Number of Referrals  Tenure in Months  ...  \
# 0  United States  Los Angeles                    0                 1  ...
# 1  United States  Los Angeles                    1                 8  ...
# 2  United States  Los Angeles                    0                18  ...
# 3  United States    Inglewood                    1                25  ...
# 4  United States     Whittier                    1                37  ...
#
#    Avg Monthly GB Download Premium Tech Support Streaming Movies  \
# ...

# %%
df.tail()
# Out:
#      Customer ID  Gender  Birth Date Married Dependents  Number of Dependents  \
# 7038  2569-WGERO  Female  1994/08/14      No         No                     0
# 7039  6840-RESVB    Male  1986/10/31     Yes        Yes                     2
# 7040  2234-XADUH  Female  1994/12/30     Yes        Yes                     2
# 7041  4801-JZAZL  Female  1992/12/15     Yes        Yes                     2
# 7042  3186-AJIEK    Male  1980/11/21      No         No                     0
#
#             Country          City  Number of Referrals  Tenure in Months  ...  \
# 7038  United States       Landers                    0                72  ...
# 7039  United States      Adelanto                    1                24  ...
# 7040  United States         Amboy                    4                72  ...
# 7041  United States  Angelus Oaks                    1                11  ...
# 7042  United States  Apple Valley                    0                66  ...
#
# ...

# %%
print(f"Number of rows: {df.shape[0]}")
print(f"Number of columns: {df.shape[1]}")
# Out:
# Number of rows: 7043
# Number of columns: 23

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Birth Date                         7043 non-null   object
#  3   Married                            7043 non-null   object
#  4   Dependents                         7043 non-null   object
#  5   Number of Dependents               7043 non-null   int64
#  6   Country                            7043 non-null   object
#  7   City                               7043 non-null   object
#  8   Number of Referrals                7043 non-null   int64
#  9   Tenure in Months                   7043 non-null   int64
#  10  Avg Monthly Long Distance Charges  7043 non-null   float64
# ...

# %%
print([repr(col) for col in df.columns])
# Out:
# ["'Customer ID'", "'Gender'", "'Birth Date'", "'Married'", "'Dependents'", "'Number of Dependents'", "'Country'", "'City'", "'Number of Referrals'", "'Tenure in Months'", "'Avg Monthly Long Distance Charges'", "'Internet Service'", "'Internet Type'", "'Avg Monthly GB Download'", "'Premium Tech Support'", "'Streaming Movies'", "'Streaming Music'", "'Contract'", "'Paperless Billing'", "'Payment Method'", "'Monthly Charge'", "'Total Refunds'", "'Satisfaction Score'"]

# %%
df.describe()
# Out:
#        Number of Dependents  Number of Referrals  Tenure in Months  \
# count           7043.000000          7043.000000       7043.000000
# mean               0.468692             1.951867         32.386767
# std                0.962802             3.001199         24.542061
# min                0.000000             0.000000          1.000000
# 25%                0.000000             0.000000          9.000000
# 50%                0.000000             0.000000         29.000000
# 75%                0.000000             3.000000         55.000000
# max                9.000000            11.000000         72.000000
#
#        Avg Monthly Long Distance Charges  Avg Monthly GB Download  \
# count                        7043.000000              7043.000000
# mean                           22.958954                20.515405
# std                            15.448113                20.418940
# min                             0.000000                 0.000000
# ...

# %% [markdown]
# #### Check Duplicated Data

# %%
duplicates = df[df.duplicated()]

print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Customer ID, Gender, Birth Date, Married, Dependents, Number of Dependents, Country, City, Number of Referrals, Tenure in Months, Avg Monthly Long Distance Charges, Internet Service, Internet Type, Avg Monthly GB Download, Premium Tech Support, Streaming Movies, Streaming Music, Contract, Paperless Billing, Payment Method, Monthly Charge, Total Refunds, Satisfaction Score]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# #### Check Missing Value

# %%
missing_values = df.isnull().sum()
print("\nMissing Values in Each Column:")
print(missing_values)
# Out:
# Missing Values in Each Column:
# Customer ID                             0
# Gender                                  0
# Birth Date                              0
# Married                                 0
# Dependents                              0
# Number of Dependents                    0
# Country                                 0
# City                                    0
# Number of Referrals                     0
# Tenure in Months                        0
# Avg Monthly Long Distance Charges       0
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download                 0
# Premium Tech Support                    0
# Streaming Movies                        0
# Streaming Music                         0
# Contract                                0
# Paperless Billing                       0
# Payment Method                          0
# Monthly Charge                          0
# ...

# %% [markdown]
# #### Numerical Column Analysis

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
print(df[numerical_cols].describe())
# Out:
#        Number of Dependents  Number of Referrals  Tenure in Months  \
# count           7043.000000          7043.000000       7043.000000
# mean               0.468692             1.951867         32.386767
# std                0.962802             3.001199         24.542061
# min                0.000000             0.000000          1.000000
# 25%                0.000000             0.000000          9.000000
# 50%                0.000000             0.000000         29.000000
# 75%                0.000000             3.000000         55.000000
# max                9.000000            11.000000         72.000000
#
#        Avg Monthly Long Distance Charges  Avg Monthly GB Download  \
# count                        7043.000000              7043.000000
# mean                           22.958954                20.515405
# std                            15.448113                20.418940
# min                             0.000000                 0.000000
# ...

# %% [markdown]
# #### Checking Unique Value

# %%
for c in df.columns:
  if df[c].dtype == 'object':
    print(f"\n")
    print(df[c].value_counts())
# Out:
# Customer ID
# 8779-QRDMV    1
# 9817-APLHW    1
# 5447-VYTKW    1
# 8871-JLMHM    1
# 7029-IJEJK    1
#              ..
# 5493-SDRDQ    1
# 9249-FXSCK    1
# 3063-QFSZL    1
# 8364-TRMMK    1
# 3186-AJIEK    1
# Name: count, Length: 7043, dtype: int64
#
#
# Gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
#
#
# Birth Date
# 2004/09/30    5
# 1973/06/07    5
# 1980/02/13    4
# 1966/06/22    4
# 1963/11/22    4
#              ..
# 1999/10/14    1
# 1973/02/09    1
# 1981/04/01    1
# 1979/12/09    1
# 1980/11/21    1
# Name: count, Length: 6002, dtype: int64
#
#
# Married
# No     3641
# Yes    3402
# Name: count, dtype: int64
#
#
# Dependents
# No     5416
# Yes    1627
# Name: count, dtype: int64
#
#
# Country
# United States    7043
# Name: count, dtype: int64
#
#
# City
# Los Angeles         293
# San Diego           285
# San Jose            112
# Sacramento          108
# San Francisco       104
#                    ...
# Jacumba               2
# ...

# %% [markdown]
# #### Boxplot For Checking Outlier in Numerical Data

# %%
c = ['Avg Monthly Long Distance Charges','Monthly Charge','Total Refunds']
plt.figure(figsize=(12, 8))
for i, col in enumerate(c, 1):
    plt.subplot(2, (len(c) + 1) // 2, i)
    df[col].plot.box()
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Check Outlier With IQR

# %%
outliers = {}

for col in c:
    Q1 = df[col].quantile(0.25)  
    Q3 = df[col].quantile(0.75)  
    IQR = Q3 - Q1                
    lower_bound = Q1 - 1.5 * IQR 
    upper_bound = Q3 + 1.5 * IQR 

    outliers[col] = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

for col, data in outliers.items():
    print(f"Outliers in column {col}:")
    print(data)
    print("\n")
# Out:
# Outliers in column Avg Monthly Long Distance Charges:
# Empty DataFrame
# Columns: [Customer ID, Gender, Birth Date, Married, Dependents, Number of Dependents, Country, City, Number of Referrals, Tenure in Months, Avg Monthly Long Distance Charges, Internet Service, Internet Type, Avg Monthly GB Download, Premium Tech Support, Streaming Movies, Streaming Music, Contract, Paperless Billing, Payment Method, Monthly Charge, Total Refunds, Satisfaction Score]
# Index: []
#
# [0 rows x 23 columns]
#
#
# Outliers in column Monthly Charge:
# Empty DataFrame
# Columns: [Customer ID, Gender, Birth Date, Married, Dependents, Number of Dependents, Country, City, Number of Referrals, Tenure in Months, Avg Monthly Long Distance Charges, Internet Service, Internet Type, Avg Monthly GB Download, Premium Tech Support, Streaming Movies, Streaming Music, Contract, Paperless Billing, Payment Method, Monthly Charge, Total Refunds, Satisfaction Score]
# Index: []
#
# [0 rows x 23 columns]
#
#
# ...

# %% [markdown]
# #### Check Data Distribution

# %%
plt.figure(figsize=(12, 8))
for i, col in enumerate(c, 1):
    plt.subplot(2, (len(c) + 1) // 2, i)
    plt.hist(df[col], bins=20, color='blue', edgecolor='black', alpha=0.7)
    plt.title(f"Distribution of {col}")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Skewness

# %%
from scipy.stats import skew
for col in c:
    print(f"Skewness of {col}: {skew(df[col])}")
# Out:
# Skewness of Avg Monthly Long Distance Charges: 0.04916542536235985
# Skewness of Monthly Charge: -0.2204774644391769
# Skewness of Total Refunds: 4.327594770080399

# %% [markdown]
# ### EDA Result
# #### Based on the EDA (Exploratory Data Analysis) of the dataset, here are the key findings:
#
# - Total of 7043 customer entries
# - There are 7043 rows of data and 23 columns of data.
# - All customers are from the United States
#
# Customer
# - Gender distribution is fairly balanced: Male (3555) vs Female (3488)
# - Majority of customers have no dependents (Dependents: No = 5416)
# - Marital status is relatively balanced: No (3641) vs Yes (3402)
# - Spread across 1106 cities with highest concentrations in Los Angeles (293) and San Diego (285)
#
# Duplicate Data
# - There are no duplicate entries in the dataset
#
# Missing Values
# - Only one column has missing values: "Internet Type" with 1526 null values
# - The missing values in Internet Type correspond exactly to customers without internet service (1526 "No" responses in Internet Service)
# - All other columns have complete data (0 missing values)
#
# Outliers
#
#     Avg Monthly Long Distance Charges:
#     - No significant outliers
#     - Data is normally distributed (skewness: 0.049)
#     - Range: $0 - $49.99
#     - IQR appears reasonable with most data between $9.21 and $36.40
#
#
#     Monthly Charge:
#     - No significant outliers
#     - Slightly left-skewed distribution (skewness: -0.22)
#     - Range: $18.25 - $118.75
#     - Even distribution across quartiles
#
#
#     Total Refunds:
#     - Significant outliers present
#     - Highly right-skewed (skewness: 4.33)
#     - Most customers have 0 refunds
#     - 525 rows identified as outliers in the refunds column
#     - Maximum refund amount: $49.79
#
# Distribution Analysis
#
# a) Numerical Variables:
#
#     Number of Dependents:
#     - Mean: 0.47
#     - Most customers have 0 dependents
#     - Right-skewed distribution
#
#
#     Tenure in Months:
#     - Mean: 32.39 months
#     - Wide spread from 1 to 72 months
#     - Fairly even distribution
#
#     Avg Monthly GB Download:
#     - Mean: 20.52 GB
#     - Range: 0-85 GB
#     - Right-skewed distribution
#
#
# b) Categorical Variables:
#
#     Gender: Balanced distribution (Male: 3555, Female: 3488)
#     Contract Type: Skewed towards Month-to-Month (3610)
#     Payment Method: Dominated by Bank Withdrawal (3909)
#     Satisfaction Score: Normal-like distribution centered around 3

# %% [markdown]
# <span style="color: blue; font-size: 19px;">Data Preparation</span>

# %% [markdown]
# #### Based on the EDA results, here are the necessary data preparation steps that should be performed:
#
# 1. Handling Missing Values
# - Handle 1526 missing value in internet type
#
# 2. Handle Outliers in Total Refunds
#
# 3. Feature Scaling/Normalization
#
# 4. Feature Encoding for categorical columns

# %% [markdown]
# #### Handle Missing Value

# %%
df['Internet Type'].fillna('Unknown', inplace=True)

# %%
print(df['Internet Type'].isnull().sum())
# Out:
# 0

# %% [markdown]
# #### Handle Outliers

# %%
median = df['Total Refunds'].median()

df['Total Refunds'] = df['Total Refunds'].fillna(median)

# %% [markdown]
# #### Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

numeric_cols = ['Number of Dependents', 'Number of Referrals', 'Tenure in Months', 
                'Avg Monthly Long Distance Charges', 'Avg Monthly GB Download', 
                'Monthly Charge', 'Total Refunds', 'Satisfaction Score']

df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %% [markdown]
# #### Encoding

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

categorical_cols = ['Gender', 'Married', 'Dependents', 'Country', 'City', 'Internet Service', 
                    'Internet Type', 'Premium Tech Support', 'Streaming Movies', 'Streaming Music', 
                    'Contract', 'Paperless Billing', 'Payment Method']

for col in categorical_cols:
    df[col] = label_encoder.fit_transform(df[col])

# %%
df.head()
# Out:
#   Customer ID  Gender  Birth Date  Married  Dependents  Number of Dependents  \
# 0  8779-QRDMV       1  1946/07/17        0           0              0.000000
# 1  7495-OOKFY       0  1950/11/12        1           1              0.111111
# 2  1658-BYGOY       1  1953/03/21        0           1              0.333333
# 3  4598-XLKNJ       0  1946/03/08        1           1              0.111111
# 4  4846-WHAFZ       0  1944/04/02        1           1              0.111111
#
#    Country  City  Number of Referrals  Tenure in Months  ...  \
# 0        0   554             0.000000          0.000000  ...
# 1        0   554             0.090909          0.098592  ...
# 2        0   554             0.000000          0.239437  ...
# 3        0   448             0.090909          0.338028  ...
# 4        0  1072             0.090909          0.507042  ...
#
#    Avg Monthly GB Download  Premium Tech Support  Streaming Movies  \
# ...

# %% [markdown]
# <span style="color: red; font-size: 19px;">B. Train K-Means Clustering, Fine Tune Using 2 Metrics and Visualize The Resulting Clustered Data</span>

# %% [markdown]
# ### Inertia

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

inertia = []
range_n_clusters = list(range(2, 11)) 

for n_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(df[numeric_cols])
    inertia.append(kmeans.inertia_)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
plt.figure(figsize=(8,6))
plt.plot(range_n_clusters, inertia, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# ### Silhouette Score

# %%
silhouette_scores = []

for n_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(df[numeric_cols])
    score = silhouette_score(df[numeric_cols], kmeans.labels_)
    silhouette_scores.append(score)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
plt.figure(figsize=(8,6))
plt.plot(range_n_clusters, silhouette_scores, marker='o')
plt.title('Silhouette Score')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.show()

#optimal_k = silhouette_scores.index(max(silhouette_scores)) + 2
#print(f"\nOptimal number of clusters based on Silhouette Score: {optimal_k}")

# %% [markdown]
# ### Calinski Harabsz Score

# %%
from sklearn.metrics import calinski_harabasz_score

ch_scores = []

for n_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    kmeans.fit(df[numeric_cols])  # Use the scaled data
    ch_score = calinski_harabasz_score(df[numeric_cols], kmeans.labels_)
    ch_scores.append(ch_score)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
plt.figure(figsize=(8, 6))
plt.plot(range_n_clusters, ch_scores, marker='o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Calinski-Harabasz Score')
plt.title('Calinski-Harabasz Score')
plt.show()

# %% [markdown]
# ### Clustered Visualization Result Using PCA

# %%
from sklearn.decomposition import PCA
import seaborn as sns

kmeans = KMeans(n_clusters=optimal_k, random_state=42)
df['Cluster'] = kmeans.fit_predict(df[numeric_cols])  

pca = PCA(n_components=2)
pca_components = pca.fit_transform(df[numeric_cols])
pca_df = pd.DataFrame(pca_components, columns=['PCA1', 'PCA2'])
pca_df['Cluster'] = df['Cluster']
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='PCA1', y='PCA2', hue='Cluster', data=pca_df, palette='viridis', s=100, alpha=0.7)
plt.title(f'K-Means Clustering (k={optimal_k}) - PCA Visualization')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(title='Cluster')
plt.show()

# %% [markdown]
# ### Clustered Visualization Result Using t-SNE

# %%
from sklearn.manifold import TSNE

kmeans = KMeans(n_clusters=optimal_k, random_state=42)
df['Cluster'] = kmeans.fit_predict(df[numeric_cols])

tsne = TSNE(n_components=2, random_state=42)
tsne_components = tsne.fit_transform(df[numeric_cols])

tsne_df = pd.DataFrame(tsne_components, columns=['t-SNE1', 't-SNE2'])
tsne_df['Cluster'] = df['Cluster']
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='t-SNE1', y='t-SNE2', hue='Cluster', data=tsne_df, palette='viridis', s=100, alpha=0.7)
plt.title(f'K-Means Clustering (k={optimal_k}) - t-SNE Visualization')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.legend(title='Cluster')
plt.show()

# %% [markdown]
# <span style="color: red; font-size: 19px;">C. Analyze Characteristics of Each Customer Cluster</span>

# %% [markdown]
# #### Cluster Centroids

# %%
centroids_df = pd.DataFrame(kmeans.cluster_centers_, columns=numeric_cols)
print("Cluster Centroids:")
print(centroids_df)
# Out:
# Cluster Centroids:
#    Number of Dependents  Number of Referrals  Tenure in Months  \
# 0              0.039238             0.075641          0.176904
# 1              0.067899             0.302896          0.768836
#
#    Avg Monthly Long Distance Charges  Avg Monthly GB Download  Monthly Charge  \
# 0                           0.444852                 0.217257        0.385375
# 1                           0.477039                 0.271058        0.558219
#
#    Total Refunds  Satisfaction Score
# 0       0.033366            0.492927
# 1       0.046856            0.645404

# %% [markdown]
# #### Cluster Summary

# %%
cluster_summary = df.groupby('Cluster')[numeric_cols].describe()
print("\nCluster Summary Statistics:")
print(cluster_summary)
# Out:
# Cluster Summary Statistics:
#         Number of Dependents                                               \
#                        count      mean       std  min  25%  50%       75%
# Cluster
# 0                     3887.0  0.039248  0.097203  0.0  0.0  0.0  0.000000
# 1                     3156.0  0.067878  0.115991  0.0  0.0  0.0  0.111111
#
#                   Number of Referrals            ... Total Refunds            \
#               max               count      mean  ...           75%       max
# Cluster                                          ...
# 0        1.000000              3887.0  0.075777  ...           0.0  1.000000
# 1        0.888889              3156.0  0.302656  ...           0.0  0.999397
#
#         Satisfaction Score
#                      count      mean       std  min   25%   50%   75%  max
# Cluster
# 0                   3887.0  0.493054  0.325634  0.0  0.25  0.50  0.75  1.0
# 1                   3156.0  0.645200  0.240937  0.0  0.50  0.75  0.75  1.0
#
# ...

# %% [markdown]
# #### Visualisation Distribution of Features Across Clusters

# %%
plt.figure(figsize=(12, 8))
for i, feature in enumerate(numeric_cols):
    plt.subplot(3, 3, i+1)
    sns.boxplot(x='Cluster', y=feature, data=df)
    plt.title(f'Distribution of {feature} by Cluster')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Analyzing Categorical Features

# %%
for col in categorical_cols:
    print(f"\nCluster distribution for {col}:")
    print(pd.crosstab(df[col], df['Cluster'], normalize='index'))
# Out:
# Cluster distribution for Gender:
# Cluster         0         1
# Gender
# 0        0.555619  0.444381
# 1        0.548242  0.451758
#
# Cluster distribution for Contract:
# Cluster          0         1
# Contract
# 0         0.812465  0.187535
# 1         0.375484  0.624516
# 2         0.197557  0.802443
#
# Cluster distribution for Payment Method:
# Cluster                0         1
# Payment Method
# 0               0.539780  0.460220
# 1               0.535104  0.464896
# 2               0.794805  0.205195
#
# Cluster distribution for Internet Service:
# Cluster                  0         1
# Internet Service
# 0                 0.642202  0.357798
# 1                 0.526917  0.473083

# %% [markdown]
# #### Detailed Cluster Characteristics

# %%
for cluster in sorted(df['Cluster'].unique()):
    cluster_data = df[df['Cluster'] == cluster]
    print(f"\nCluster {cluster} ({len(cluster_data)} customers):")
    
    print("\nNumerical Features (Mean):")
    print(cluster_data[numerical_features].mean().round(2))
    

    print("\nTop Categories:")
    for col in categorical_features:
        print(f"\n")
        print(cluster_data[col].value_counts(normalize=True).nlargest(2).round(3))
    print("-" * 30)
# Out:
# Cluster 0 (3887 customers):
#
# Numerical Features (Mean):
# Number of Dependents                 0.04
# Number of Referrals                  0.08
# Tenure in Months                     0.18
# Avg Monthly Long Distance Charges    0.44
# Avg Monthly GB Download              0.22
# Monthly Charge                       0.39
# Total Refunds                        0.03
# Satisfaction Score                   0.49
# dtype: float64
#
# Top Categories:
#
#
# Gender
# 1    0.501
# 0    0.499
# Name: proportion, dtype: float64
#
#
# Contract
# 0    0.755
# 1    0.150
# Name: proportion, dtype: float64
#
#
# Payment Method
# 0    0.543
# 1    0.378
# Name: proportion, dtype: float64
#
#
# Internet Service
# 1    0.748
# 0    0.252
# Name: proportion, dtype: float64
# ------------------------------
#
# Cluster 1 (3156 customers):
#
# Numerical Features (Mean):
# Number of Dependents                 0.07
# Number of Referrals                  0.30
# Tenure in Months                     0.77
# ...

# %% [markdown]
# Based on the K-Means clustering analysis, i have identified two distinct customer segments with unique characteristics:
#
# - Cluster 0 represents customers who have lower values for most features such as the number of dependents, referrals, and monthly charges. These customers tend to have shorter tenures and lower satisfaction scores. They likely represent a group with minimal engagement or lower-value customers. The majority of them have basic contracts and prefer lower-cost internet services. This group could benefit from targeted campaigns to increase engagement, encourage longer-term contracts, or introduce additional services.
#
# - Cluster 1 consists of customers with higher values in features such as the number of referrals, tenure, monthly charges, and satisfaction scores. This segment includes more loyal customers with longer subscriptions and higher spending. They are also more likely to have premium internet services and higher satisfaction levels. This group could be targeted with loyalty programs, premium service offerings, or exclusive benefits to strengthen retention and increase the lifetime value of these customers.

# %% [markdown]
# <span style="color: red; font-size: 19px;">D. Explanation Video</span>

# %% [markdown]
# #### Youtube
# https://youtu.be/AYCKb1FQWKE
#
# #### Google Drive
# https://drive.google.com/file/d/1GqpwXunYQIp9tx2v1eWC2U2bmcuLYq2I/view?usp=sharing
